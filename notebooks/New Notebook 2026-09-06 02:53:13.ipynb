# %%
import json
import os
import pandas as pd
from f1_pipeline.json_utils import find_table_and_list

path = '/Volumes/f1/bronze/raw_files/results/season=2026.json'
path = '/Volumes/f1/bronze/raw_files/results/season=2026.json'

with open(path) as f:
  data = json.load(f)
  
table = find_table_and_list(data['MRData'])
print(json.dumps(table, indent=4))

df = pd.DataFrame(table)
display(df)
